# %%
import geopandas as gpd
import contextily as cx

# %%
bp_grid = gpd.read_file("../data/geojson/bp_grid_eov.geojson")

# %%
area = gpd.read_file("../data/geojson/map_around_cub.geojson").set_crs(4326).to_crs(23700)

# %%
bp_grid
# Out:
#         id           left           top          right        bottom  \
# 0        1  640756.570423  252181.63715  641256.570423  251681.63715
# 1        2  640756.570423  251681.63715  641256.570423  251181.63715
# 2        3  640756.570423  251181.63715  641256.570423  250681.63715
# 3        4  640756.570423  250681.63715  641256.570423  250181.63715
# 4        5  640756.570423  250181.63715  641256.570423  249681.63715
# ...    ...            ...           ...            ...           ...
# 3653  3654  671256.570423  225181.63715  671756.570423  224681.63715
# 3654  3655  671256.570423  224681.63715  671756.570423  224181.63715
# 3655  3656  671256.570423  224181.63715  671756.570423  223681.63715
# 3656  3657  671256.570423  223681.63715  671756.570423  223181.63715
# 3657  3658  671256.570423  223181.63715  671756.570423  222681.63715
#
#       row_index  col_index                                           geometry
# ...

# %%
area.plot()
# Out:
# <Axes: >
